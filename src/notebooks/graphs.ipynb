# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("F:/Cell Detection Visual Data/Data/BCCD Dataset with mask/test/pred/res/stats/stats.csv")
plt.figure(figsize=(6, 8))
print(df.columns)
df_plot = df.drop(columns=["name", "TP", "FP", "FN"])
colors = ['#FF6347', '#8A2BE2', '#00FA9A', '#FF4500', '#2E8B57', 
          '#FFD700', '#D2691E', '#6495ED', '#DC143C']
for i, column in enumerate(df_plot.columns, start=1):
    plt.subplot(3, 3, i)  
    sns.violinplot(data=df_plot, y=column, orient="v", color=colors[i-1])
    plt.title(f'{column}')
plt.tight_layout()  
plt.show()

plt.figure(figsize=(8, 6))
sns.violinplot(data=df_plot, palette=colors)
plt.tight_layout()  
plt.show()
# Out:
# Index(['name', 'DICE', 'AJI', 'AJI+', 'PQ', 'BF score', 'recall', 'precision',
#        'FDR', 'F1', 'TP', 'FP', 'FN'],
#       dtype='object')
